# %% [markdown]
# <a href="https://colab.research.google.com/github/faisu6339-glitch/Statistics/blob/main/Measure_Of_Central_Tendency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statistics

# %%
#Mean

# %%
data=[1,1,1,2,2,1,2,3,3,4,5,6,9,7,8,7,8]

# %%
statistics.mean(data)
# Out:
# 4.117647058823529

# %%
# Load the mpg dataset
mpg_df = sns.load_dataset("mpg")

# %%
# Display the first few rows of the DataFrame
print(mpg_df.head())
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
statistics.mean(mpg_df["cylinders"])
# Out:
# 5.454773869346734

# %%
statistics.mean(mpg_df["mpg"])
# Out:
# 23.514572864321607

# %%
mpg_df.mean(numeric_only=True)
# Out:
# mpg               23.514573
# cylinders          5.454774
# displacement     193.425879
# horsepower       104.469388
# weight          2970.424623
# acceleration      15.568090
# model_year        76.010050
# dtype: float64

# %%
#Median

# %%
data=[1,1,1,2,2,1,2,3,3,4,5,6,9,7,8,7,8,80]

# %%
 statistics.median(data)
# Out:
# 3

# %%
 statistics.mode(data)
# Out:
# 1

# %%
mpg_df.mode()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  13.0        4.0          97.0       150.0    1985          14.5
# 1   NaN        NaN           NaN         NaN    2130           NaN
#
#    model_year origin        name
# 0        73.0    usa  ford pinto
# 1         NaN    NaN         NaN

# %%
len(mpg_df[mpg_df["weight"]==1985])
# Out:
# 4

# %%
len(mpg_df[mpg_df["weight"]==2130])
# Out:
# 4

# %%
len(mpg_df[mpg_df["name"]=="ford pinto"])
# Out:
# 6
