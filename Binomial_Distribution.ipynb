# %% [markdown]
# <a href="https://colab.research.google.com/github/faisu6339-glitch/Statistics/blob/main/Binomial_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.stats import binom

n = 10      # trials
p = 0.3     # success probability
k = 4       # successes

prob = binom.pmf(k, n, p)
print("Probability:", prob)

# %%
import numpy as np

data = np.random.binomial(n=10, p=0.5, size=1000)
print(data[:10])

# %%
import matplotlib.pyplot as plt
from scipy.stats import binom
import numpy as np

n = 10
p = 0.5
x = np.arange(0, n+1)

plt.bar(x, binom.pmf(x, n, p))
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.title("Binomial Distribution")
plt.show()
